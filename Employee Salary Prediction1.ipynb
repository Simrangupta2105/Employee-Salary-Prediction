# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sal_data = pd.read_csv(r"C:\Users\simra\OneDrive\Desktop\adult 3.csv")
sal_data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
sal_data.shape
# Out:
# (48842, 15)

# %%
sal_data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
sal_data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
sal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
sal_data[sal_data.duplicated()]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 864     24           Private  194630     Bachelors               13
# 11189   37           Private   52870     Bachelors               13
# 11212   29           Private   36440     Bachelors               13
# 13848   30           Private  180317     Assoc-voc               11
# 15960   18      Self-emp-inc  378036          12th                8
# 18476   39           Private  184659       HS-grad                9
# 19399   19           Private  130431       5th-6th                3
# 19726   41           Private  116391     Bachelors               13
# 20606   25           Private  308144     Bachelors               13
# 21162   25           Private  308144     Bachelors               13
# 21385   90           Private   52386  Some-college               10
# 24361   21           Private  243368     Preschool                1
# 25189   29                 ?   41281     Bachelors               13
# ...

# %%
sal_data1 = sal_data.drop_duplicates(keep='first').copy()
sal_data1.shape
# Out:
# (48790, 15)

# %%
sal_data1.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sal_data1.dropna(how='any', inplace=True)

# %%
sal_data1.shape
# Out:
# (48790, 15)

# %%
sal_data1.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
#Data Exploration and Visualisation
sal_data1.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48790.000000  4.879000e+04     48790.000000  48790.000000
# mean      38.652798  1.896690e+05        10.078807   1080.217688
# std       13.708493  1.056172e+05         2.570046   7455.905921
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175550e+05         9.000000      0.000000
# 50%       37.000000  1.781385e+05        10.000000      0.000000
# 75%       48.000000  2.376062e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48790.000000    48790.000000
# mean      87.595573       40.425886
# std      403.209129       12.392729
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
sal_data1['income_num'] = sal_data1['income'].apply(lambda x: 1 if x == '>50K' else 0)
corr = sal_data1[['age', 'hours-per-week', 'income_num']].corr()
corr
# Out:
#                      age  hours-per-week  income_num
# age             1.000000        0.071223    0.230144
# hours-per-week  0.071223        1.000000    0.227664
# income_num      0.230144        0.227664    1.000000

# %%
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
sal_data1['education'].value_counts()
# Out:
# education
# HS-grad         15770
# Some-college    10863
# Bachelors        8013
# Masters          2656
# Assoc-voc        2060
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           954
# Prof-school       834
# 9th               756
# 12th              655
# Doctorate         594
# 5th-6th           507
# 1st-4th           245
# Preschool          81
# Name: count, dtype: int64

# %%
sal_data1['education'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='education'>

# %%
sal_data1['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6165
# Craft-repair         6102
# Exec-managerial      6082
# Adm-clerical         5606
# Sales                5501
# Other-service        4919
# Machine-op-inspct    3017
# ?                    2805
# Transport-moving     2355
# Handlers-cleaners    2071
# Farming-fishing      1485
# Tech-support         1445
# Protective-serv       982
# Priv-house-serv       240
# Armed-Forces           15
# Name: count, dtype: int64

# %%
sal_data1['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv', '?',
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces'],
#       dtype=object)

# %%
sal_data1['gender'].value_counts().plot(kind = 'barh')
# Out:
# <Axes: ylabel='gender'>

# %%
sal_data1.age.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sal_data1.age.plot(kind = 'box')
# Out:
# <Axes: >

# %%
sal_data1['educational-num'].plot(kind='box', color='blue')
plt.title('Education Level Distribution')
plt.ylabel('Educational-Num')
plt.grid(True)
plt.show()

# %%
sal_data1['income_num'] = sal_data1['income'].apply(lambda x: 1 if x == '>50K' else 0)
sal_data1['income_num'].plot(kind='box')
# Out:
# <Axes: >

# %%
sal_data1['income_num'] = sal_data1['income'].apply(lambda x: 1 if x == '>50K' else 0)
sal_data1['income_num'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sal_data1.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0   25    Private  226802          1                7       Never-married
# 1   38    Private   89814         11                9  Married-civ-spouse
# 2   28  Local-gov  336951          7               12  Married-civ-spouse
# 3   44    Private  160323         15               10  Married-civ-spouse
# 4   18          ?  103497         15               10       Never-married
#
#    occupation relationship   race  gender  capital-gain  capital-loss  \
# 0           7    Own-child  Black    Male             0             0
# 1           5      Husband  White    Male             0             0
# 2          11      Husband  White    Male             0             0
# 3           7      Husband  Black    Male          7688             0
# 4           0    Own-child  White  Female             0             0
#
#    hours-per-week native-country income  income_num  gender_Encode
# ...

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
Label_Encoder = LabelEncoder()

# %%
sal_data1['gender_Encode'] = Label_Encoder.fit_transform(sal_data1['gender'])

# %%
sal_data1['education_Encode'] = Label_Encoder.fit_transform(sal_data1['education'])

# %%
sal_data1['occupation_Encode'] = Label_Encoder.fit_transform(sal_data1['occupation'])

# %%
#Data after Label Encoding
sal_data1.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0   25    Private  226802          1                7       Never-married
# 1   38    Private   89814         11                9  Married-civ-spouse
# 2   28  Local-gov  336951          7               12  Married-civ-spouse
# 3   44    Private  160323         15               10  Married-civ-spouse
# 4   18          ?  103497         15               10       Never-married
#
#    occupation relationship   race  gender  capital-gain  capital-loss  \
# 0           7    Own-child  Black    Male             0             0
# 1           5      Husband  White    Male             0             0
# 2          11      Husband  White    Male             0             0
# 3           7      Husband  Black    Male          7688             0
# 4           0    Own-child  White  Female             0             0
#
#    hours-per-week native-country income  income_num  gender_Encode
# ...

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
sal_data1['education_Encode'] = Label_Encoder.fit_transform(sal_data1['education'])

# %%
sal_data1['occupation'] = Label_Encoder.fit_transform(sal_data1['occupation'])

# %%
sal_data1.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0   25    Private  226802          1                7       Never-married
# 1   38    Private   89814         11                9  Married-civ-spouse
# 2   28  Local-gov  336951          7               12  Married-civ-spouse
# 3   44    Private  160323         15               10  Married-civ-spouse
# 4   18          ?  103497         15               10       Never-married
#
#    occupation relationship   race  gender  ...  capital-loss  hours-per-week  \
# 0           7    Own-child  Black    Male  ...             0              40
# 1           5      Husband  White    Male  ...             0              50
# 2          11      Husband  White    Male  ...             0              40
# 3           7      Husband  Black    Male  ...             0              40
# 4           0    Own-child  White  Female  ...             0              30
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
sal_data1['age_scaled'] = std_scaler.fit_transform(sal_data1[['age']])
sal_data1['hours-per-week_scaled'] = std_scaler.fit_transform(sal_data1[['hours-per-week']])

# %%
sal_data1.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num      marital-status  \
# 0   25    Private  226802          1                7       Never-married
# 1   38    Private   89814         11                9  Married-civ-spouse
# 2   28  Local-gov  336951          7               12  Married-civ-spouse
# 3   44    Private  160323         15               10  Married-civ-spouse
# 4   18          ?  103497         15               10       Never-married
#
#    occupation relationship   race  gender  ...  capital-loss  hours-per-week  \
# 0           7    Own-child  Black    Male  ...             0              40
# 1           5      Husband  White    Male  ...             0              50
# 2          11      Husband  White    Male  ...             0              40
# 3           7      Husband  Black    Male  ...             0              40
# 4           0    Own-child  White  Female  ...             0              30
#
# ...

# %%
x= sal_data1[['age_scaled','gender_Encode','education_Encode','occupation_Encode','hours-per-week_scaled']]
y= sal_data1['income']

# %%
x.head()
# Out:
#    age_scaled  gender_Encode  education_Encode  occupation_Encode  \
# 0   -0.995947              1                 1                  7
# 1   -0.047620              1                11                  5
# 2   -0.777103              1                 7                 11
# 3    0.390069              1                15                  7
# 4   -1.506585              0                15                  0
#
#    hours-per-week_scaled
# 0              -0.034366
# 1               0.772567
# 2              -0.034366
# 3              -0.034366
# 4              -0.841299

# %%
##Splitting the data into training and testing

from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state =23)

# %%
x_train.head()
# Out:
#        age_scaled  gender_Encode  education_Encode  occupation_Encode  \
# 27854   -1.141844              0                11                  0
# 45585   -1.068896              1                11                  6
# 33776   -1.287740              0                11                  1
# 13275    0.900707              0                 6                  8
# 19005    0.463017              0                 9                 10
#
#        hours-per-week_scaled
# 27854              -0.034366
# 45585              -0.034366
# 33776              -1.244766
# 13275              -0.195753
# 19005               0.772567

# %%
x_train.shape, y_train.shape #80%
# Out:
# ((39032, 5), (39032,))

# %%
x_test.shape, y_test.shape #20%
# Out:
# ((9758, 5), (9758,))

# %%
#Model development
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# %%
Linear_regression_model = LinearRegression()
Linear_regression_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = Linear_regression_model.predict(x_test)
print(y_pred_lr)
# Out:
# [ 0.38860788  0.35616957  0.26071278 ...  0.33508236 -0.06627807
#   0.32104892]

# %%
## Model Predictions
y_pred_lr = Linear_regression_model.predict(x_test)
y_pred_lr
# Out:
# array([ 0.38860788,  0.35616957,  0.26071278, ...,  0.33508236,
#        -0.06627807,  0.32104892])

# %%
df = pd.DataFrame({'y_Actual' :y_test, 'y_predicted': y_pred_lr})
df['Error'] = df['y_Actual'] - df['y_predicted']
df['abs_error'] = abs(df['Error'])
df
# Out:
#       y_Actual  y_predicted     Error  abs_error
# 0            0     0.388608 -0.388608   0.388608
# 1            1     0.356170  0.643830   0.643830
# 2            1     0.260713  0.739287   0.739287
# 3            1     0.358451  0.641549   0.641549
# 4            0     0.363620 -0.363620   0.363620
# ...        ...          ...       ...        ...
# 9753         0     0.136738 -0.136738   0.136738
# 9754         0     0.095532 -0.095532   0.095532
# 9755         0     0.335082 -0.335082   0.335082
# 9756         0    -0.066278  0.066278   0.066278
# 9757         0     0.321049 -0.321049   0.321049
#
# [9758 rows x 4 columns]

# %%
Mean_absolute_Error = df['abs_error'].mean()
Mean_absolute_Error
# Out:
# np.float64(0.32512780558842813)

# %%
#Model Evaluation
from sklearn.metrics import accuracy_score, r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
r2_score(y_test, y_pred_lr)
# Out:
# 0.13113209297603645

# %%
print(f'Accuracy of the model= {round(r2_score(y_test, y_pred_lr),4)*100}%')
# Out:
# Accuracy of the model= 13.11%

# %%
#Mean Absolute Error
round(mean_absolute_error(y_test, y_pred_lr),2)
# Out:
# 0.33

# %%
print(f"Mean Absolute Error = {round(mean_absolute_error(y_test, y_pred_lr),2)}")
# Out:
# Mean Absolute Error = 0.33

# %%
#Mean Squared Error
mse=  round(mean_squared_error(y_test, y_pred_lr),2)

# %%
print(f"Mean SquaredError = {round(mean_squared_error(y_test, y_pred_lr),2)}")
# Out:
# Mean SquaredError = 0.16

# %%
#Root Mean Squared Error
print('Root Mean Squared Error(RMSE)= ', mse**(0.5))
# Out:
# Root Mean Squared Error(RMSE)=  0.4

# %%
#Coefficients
Linear_regression_model.coef_
# Out:
# array([0.08715796, 0.1408899 , 0.00882124, 0.00611608, 0.0717238 ])

# %%
#intercepts
Linear_regression_model.intercept_
# Out:
# np.float64(0.014170307136102234)

# %%
#Customise Prediction
sal_data1.head
# Out:
# <bound method NDFrame.head of        age     workclass  fnlwgt  education  educational-num  \
# 0       25       Private  226802          1                7
# 1       38       Private   89814         11                9
# 2       28     Local-gov  336951          7               12
# 3       44       Private  160323         15               10
# 4       18             ?  103497         15               10
# ...    ...           ...     ...        ...              ...
# 48837   27       Private  257302          7               12
# 48838   40       Private  154374         11                9
# 48839   58       Private  151910         11                9
# 48840   22       Private  201490         11                9
# 48841   52  Self-emp-inc  287927         11                9
#
#            marital-status  occupation relationship   race  gender  ...  \
# 0           Never-married           7    Own-child  Black    Male  ...
# ...

# %%
age1 = std_scaler.transform([[49]])     
age= -0.777103                              

gender = 1                              
education = 7                            
occupation = 11                             

hours-per-week1 = std_scaler.transform([[40]]) 
hours_per_week = -0.034366
# Out:
#   Cell In[237], line 8
#     hours-per-week1 = std_scaler.transform([[40]])
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
std_scaler.transform([[15]])[0][0]
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-2.05169879]])

# %%
Emp_income = Linear_regression_model.predict([[age, gender, education, occupation, hours_per_week]])
Emp_income
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7.28147646])

# %%
print("Salary of that Employee with above Attributes = ", Emp_income[0])
# Out:
# Salary of that Employee with above Attributes =  7.28147646458154
